# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from pyfm import pylibfm
from fastFM import als
import scipy
import itertools
import pickle

# sklearn lib
from sklearn.feature_extraction import DictVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score, roc_auc_score
% matplotlib inline
# Out:
# /Users/apple/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
amazon = pd.read_csv("no_outlier_data.csv")
class_desc = pd.read_csv("description.csv")
with open('cluster_index.pickle', 'rb') as handle:
    kcluster = pickle.load(handle)

# %%
def format_data(df, users_name, items_name, col, rename=[]):
    df = df[col]
    users = sorted(df[users_name].unique().tolist())
    items = sorted(df[items_name].unique().tolist())
    if rename:
        df = df.rename(index=str, columns=dict(zip(col, rename)))
    return users, items, df.to_dict(orient="records")

# %% [markdown]
# ## Preprocessing

# %%
def preprocess(df, users_name, items_name, col, rename=[]):
    # Recevie sorted users items list and format data [{users:, items:, rating:}]
    users, items, data = format_data(df, users_name, items_name, col=col, rename=rename)
    
    # Vectorize and transform to csr_matrix
    dv = DictVectorizer()
    matrix = dv.fit_transform(data).toarray()
    
    # split data
    x_train, x_test, y_train, y_test = train_test_split(matrix[:,1:], matrix[:,:1], test_size=0.2)
    x_train = scipy.sparse.csr_matrix(x_train)
    x_test = scipy.sparse.csr_matrix(x_test)
    y_train = y_train.T[0]
    y_test = y_test.T[0]
    return users, items, x_train, x_test, y_train, y_test

# %% [markdown]
# ## Factorization Machine

# %%
def my_FM(x_train, y_train, x_test, y_test):
    # FM process
    fm = als.FMRegression(n_iter=1000, init_stdev=0.1, rank=2, l2_reg_w=0.1, l2_reg_V=0.5)
    fm.fit(x_train, y_train)
    
    # Prediction
    y_pred = fm.predict(x_test)
    mse = mean_squared_error(y_test, y_pred)
    acc = round(100*accuracy_score((y_test>3.5).astype("int"),(y_pred>3.5).astype("int")),2)
    auc = round(100*roc_auc_score((y_test>3.5).astype("int"),(y_pred>3.5).astype("int")),2)
    
    print("FM MSE: %.4f" % mse)
    print("FM ACC: %s％" % acc)
    print("FM AUC: %s％" % auc)
    
    return fm, mse, acc, auc

# %% [markdown]
# ## Post-processing

# %%
def fill_prediction_matrix(users, items, fm):
    pairs = [{"1_user": user, "2_item": item} for (user, item) in itertools.product(users, items)]
    
    dv = DictVectorizer()
    relation_matrix = scipy.sparse.csr_matrix(dv.fit_transform(pairs))
    
    pred = fm.predict(relation_matrix)
    return pred, pairs

# %% [markdown]
# # Main: Within Category

# %%
def main(df, kcluster):
    RES, MSE, ACC, AUC = dict(), dict(), dict(), dict()
    for key in kcluster:
        print("Cluster: %s" % key)
        cluster_item = class_desc.iloc[kcluster[key]]['asin'].values.tolist()
        table = df.loc[df['asin'].isin(cluster_item)][['asin', 'reviewer', 'star_rating']]
        users, items, x_train, x_test, y_train, y_test = preprocess(table, 'reviewer', 'asin', 
                                                    ["asin", "reviewer", "star_rating"], 
                                                    rename=["2_item", "1_user", "0_rating"])
        try:
            fm, mse, acc, auc = my_FM(x_train, y_train, x_test, y_test)
            pred, pairs = fill_prediction_matrix(users, items, fm)
            for i, p in enumerate(pred):
                p = 1 if p < 1 else 5 if p > 5 else round(p, 4)
                pairs[i]["0_rating"] = p
            RES[key] = pd.DataFrame(data=pairs)
        except:
            RES[key] = np.nan
            mse, acc, auc = np.nan, np.nan, np.nan

        MSE[key] = mse
        ACC[key] = acc
        AUC[key] = auc
        print("\n")
    return RES, MSE, ACC, AUC

# %%
RES, MSE, ACC, AUC = main(amazon, kcluster)
# Out:
# Cluster: 0
# FM MSE: 1.9810
# FM ACC: 68.81％
# FM AUC: 55.55％
#
#
# Cluster: 1
# FM MSE: 1.4989
# FM ACC: 72.56％
# FM AUC: 70.27％
#
#
# Cluster: 2
# FM MSE: 1.5611
# FM ACC: 68.38％
# FM AUC: 61.15％
#
#
# Cluster: 3
# FM MSE: 1.5904
# FM ACC: 67.99％
# FM AUC: 60.52％
#
#
# Cluster: 4
# FM MSE: 1.6888
# FM ACC: 71.46％
# FM AUC: 60.63％
#
#
# Cluster: 5
# FM MSE: 1.8677
# FM ACC: 71.47％
# FM AUC: 64.8％
#
#
# Cluster: 6
# FM MSE: 1.6499
# FM ACC: 76.83％
# FM AUC: 57.75％
#
#
# Cluster: 7
# FM MSE: 2.2705
# FM ACC: 76.13％
# FM AUC: 59.19％
#
#
# Cluster: 8
# FM MSE: 1.6069
# FM ACC: 77.41％
# FM AUC: 58.85％
#
#
# Cluster: 9
# FM MSE: 0.8177
# FM ACC: 89.62％
# FM AUC: 52.66％
#
#
# Cluster: 10
# FM MSE: 1.4908
# FM ACC: 72.28％
# FM AUC: 55.74％
#
#
# Cluster: 11
# FM MSE: 1.8058
# FM ACC: 72.48％
# FM AUC: 61.67％
#
#
# Cluster: 12
# FM MSE: 1.6243
# FM ACC: 71.07％
# FM AUC: 70.45％
#
#
# Cluster: 13
# FM MSE: 1.7309
# FM ACC: 64.18％
# FM AUC: 64.43％
#
#
# Cluster: 14
# FM MSE: 1.2418
# FM ACC: 83.2％
# FM AUC: 54.62％
#
#
# Cluster: 15
# FM MSE: 1.4305
# FM ACC: 76.83％
# FM AUC: 59.75％
#
#
# Cluster: 16
# FM MSE: 1.0688
# FM ACC: 84.27％
# FM AUC: 56.26％
#
#
# Cluster: 17
# FM MSE: 2.0477
# FM ACC: 67.33％
# FM AUC: 63.83％
#
#
# Cluster: 18
# FM MSE: 1.4833
# FM ACC: 78.38％
# FM AUC: 59.51％
#
#
# Cluster: 19
# FM MSE: 1.9447
# FM ACC: 67.5％
# FM AUC: 60.77％
#
#
# Cluster: 20
# FM MSE: 2.1996
# FM ACC: 66.21％
# FM AUC: 57.01％
#
#
# Cluster: 21
# FM MSE: 1.4463
# FM ACC: 81.97％
# FM AUC: 71.13％
#
#
# Cluster: 22
# FM MSE: 1.6915
# FM ACC: 71.61％
# FM AUC: 60.4％
#
#
# Cluster: 23
# FM MSE: 1.5402
# FM ACC: 77.19％
# FM AUC: 64.81％
#
#
# Cluster: 24
# FM MSE: 2.3489
# FM ACC: 60.42％
# FM AUC: 60.95％
#
#
# Cluster: 25
# FM MSE: 1.7780
# FM ACC: 67.39％
# FM AUC: 66.06％
#
#
# Cluster: 26
# FM MSE: 1.9145
# FM ACC: 69.62％
# FM AUC: 55.12％
#
#
# Cluster: 27
# FM MSE: 1.7405
# FM ACC: 75.02％
# FM AUC: 56.5％
#
#
# Cluster: 28
# FM MSE: 1.2880
# FM ACC: 81.91％
# FM AUC: 62.82％
#
#
# Cluster: 29
# FM MSE: 1.1948
# FM ACC: 82.29％
# FM AUC: 57.46％
#
#
# Cluster: 30
# FM MSE: 1.6121
# FM ACC: 75.07％
# FM AUC: 64.93％
#
#
# Cluster: 31
# FM MSE: 1.9624
# FM ACC: 69.37％
# FM AUC: 50.17％
#
#
# Cluster: 32
# FM MSE: 2.0040
# FM ACC: 65.56％
# FM AUC: 60.23％
#
#
# Cluster: 33
# FM MSE: 1.2689
# FM ACC: 82.75％
# FM AUC: 54.21％
#
#
# Cluster: 34
# FM MSE: 1.6977
# FM ACC: 65.06％
# FM AUC: 63.8％
#
#
# Cluster: 35
# FM MSE: 1.7876
# FM ACC: 69.64％
# FM AUC: 64.33％
#
#
# Cluster: 36
# FM MSE: 1.7937
# FM ACC: 73.77％
# FM AUC: 59.58％
#
#
# Cluster: 37
# FM MSE: 1.4506
# FM ACC: 72.73％
# FM AUC: 65.9％
#
#
# Cluster: 38
# FM MSE: 1.9890
# FM ACC: 73.33％
# FM AUC: 51.11％
#
#
# Cluster: 39
# FM MSE: 1.9190
# FM ACC: 65.12％
# FM AUC: 55.45％
#
#
# Cluster: 40
# FM MSE: 1.7505
# FM ACC: 71.91％
# FM AUC: 61.6％
#
#
# Cluster: 41
# FM MSE: 1.8613
# FM ACC: 70.83％
# FM AUC: 60.94％
#
#
# Cluster: 42
# FM MSE: 1.9355
# FM ACC: 67.07％
# FM AUC: 62.07％
#
#
# Cluster: 43
# FM MSE: 1.9154
# FM ACC: 63.72％
# FM AUC: 54.84％
#
#
# Cluster: 44
# FM MSE: 1.8060
# FM ACC: 69.13％
# FM AUC: 61.39％
#
#
# Cluster: 45
# FM MSE: 1.5163
# FM ACC: 79.22％
# FM AUC: 60.11％
#
#
# Cluster: 46
# FM MSE: 1.5218
# FM ACC: 77.41％
# FM AUC: 63.56％
#
#
# Cluster: 47
# FM MSE: 0.6948
# FM ACC: 93.2％
# FM AUC: 50.0％
#
#
# Cluster: 48
# FM MSE: 1.6790
# FM ACC: 71.2％
# FM AUC: 62.86％
#
#
# Cluster: 49
# FM MSE: 1.4352
# FM ACC: 75.85％
# FM AUC: 55.28％
#
#
# Cluster: 50
# FM MSE: 1.7544
# FM ACC: 63.64％
# FM AUC: 58.38％
#
#
# Cluster: 51
# FM MSE: 1.5330
# FM ACC: 66.67％
# FM AUC: 66.86％
#
#
# Cluster: 52
# FM MSE: 2.1789
# FM ACC: 64.27％
# FM AUC: 63.08％
#
#
# Cluster: 53
# FM MSE: 1.1158
# FM ACC: 81.36％
# FM AUC: 54.79％
#
#
# Cluster: 54
# FM MSE: 1.5883
# FM ACC: 70.0％
# FM AUC: 65.26％
#
#
# Cluster: 55
# FM MSE: 1.3679
# FM ACC: 76.6％
# FM AUC: 62.04％
#
#
# Cluster: 56
# FM MSE: 1.1945
# FM ACC: 72.47％
# FM AUC: 60.31％
#
#
# Cluster: 57
# FM MSE: 2.0421
# FM ACC: 71.1％
# FM AUC: 59.19％
#
#
# Cluster: 58
# FM MSE: 1.6311
# FM ACC: 71.01％
# FM AUC: 60.38％
#
#
# Cluster: 59
# FM MSE: 1.1890
# FM ACC: 84.44％
# FM AUC: 55.49％
#
#
# Cluster: 60
# FM MSE: 2.0833
# FM ACC: 69.0％
# FM AUC: 65.22％
#
#
# Cluster: 61
# FM MSE: 1.6255
# FM ACC: 70.87％
# FM AUC: 56.18％
#
#
# Cluster: 62
# FM MSE: 1.4745
# FM ACC: 66.67％
# FM AUC: 57.56％
#
#
# Cluster: 63
# FM MSE: 1.8741
# FM ACC: 73.53％
# FM AUC: 71.29％
#
#
# Cluster: 64
# FM MSE: 1.8689
# FM ACC: 70.03％
# FM AUC: 63.88％
#
#
# Cluster: 65
# FM MSE: 1.4316
# FM ACC: 77.25％
# FM AUC: 61.11％
#
#
# Cluster: 66
# FM MSE: 1.8941
# FM ACC: 72.17％
# FM AUC: 66.26％
#
#
# Cluster: 67
# FM MSE: 1.6383
# FM ACC: 75.0％
# FM AUC: 59.59％
#
#
# Cluster: 68
# FM MSE: 2.0280
# FM ACC: 71.08％
# FM AUC: 61.05％
#
#
# Cluster: 69
# FM MSE: 1.8781
# FM ACC: 71.89％
# FM AUC: 54.09％
#
#
# Cluster: 70
# FM MSE: 1.6667
# FM ACC: 72.06％
# FM AUC: 54.73％
#
#
# Cluster: 71
# FM MSE: 2.1701
# FM ACC: 65.32％
# FM AUC: 59.47％
#
#
# Cluster: 72
# FM MSE: 1.8464
# FM ACC: 73.48％
# FM AUC: 57.33％
#
#
# Cluster: 73
# FM MSE: 2.0202
# FM ACC: 62.9％
# FM AUC: 57.48％
#
#
# Cluster: 74
# FM MSE: 1.6220
# FM ACC: 74.3％
# FM AUC: 53.3％
#
#
# Cluster: 75
# FM MSE: 1.4880
# FM ACC: 77.21％
# FM AUC: 60.51％
#
#
# Cluster: 76
# FM MSE: 1.6441
# FM ACC: 78.31％
# FM AUC: 61.8％
#
#
# Cluster: 77
# FM MSE: 1.6516
# FM ACC: 74.83％
# FM AUC: 65.36％
#
#
# Cluster: 78
# FM MSE: 1.6948
# FM ACC: 72.35％
# FM AUC: 58.13％
#
#
# Cluster: 79
# FM MSE: 0.9750
# FM ACC: 87.36％
# FM AUC: 71.25％
#
#
# Cluster: 80
# FM MSE: 2.7193
# FM ACC: 57.14％
# FM AUC: 57.33％
#
#
# Cluster: 81
# FM MSE: 1.5848
# FM ACC: 72.48％
# FM AUC: 69.07％
#
#
# Cluster: 82
# FM MSE: 1.6453
# FM ACC: 71.58％
# FM AUC: 57.37％
#
#
# Cluster: 83
# FM MSE: 2.0126
# FM ACC: 72.12％
# FM AUC: 54.4％
#
#
# Cluster: 84
# FM MSE: 1.2299
# FM ACC: 83.65％
# FM AUC: 50.15％
#
#
# Cluster: 85
# FM MSE: 1.2882
# FM ACC: 78.56％
# FM AUC: 53.92％
#
#
# Cluster: 86
# FM MSE: 1.4492
# FM ACC: 77.03％
# FM AUC: 51.59％
#
#
# Cluster: 87
# FM MSE: 1.6047
# FM ACC: 72.6％
# FM AUC: 59.03％
#
#
# Cluster: 88
# FM MSE: 1.4350
# FM ACC: 76.77％
# FM AUC: 56.31％
#
#
# Cluster: 89
# FM MSE: 1.7711
# FM ACC: 67.07％
# FM AUC: 60.64％
#
#
# Cluster: 90
# FM MSE: 1.6018
# FM ACC: 70.76％
# FM AUC: 61.74％
#
#
# Cluster: 91
# FM MSE: 1.7457
# FM ACC: 72.29％
# FM AUC: 61.72％
#
#
# Cluster: 92
# FM MSE: 1.9122
# FM ACC: 72.35％
# FM AUC: 57.29％
#
#
# Cluster: 93
# FM MSE: 2.0533
# FM ACC: 68.1％
# FM AUC: 64.34％
#
#
# Cluster: 94
# FM MSE: 1.3997
# FM ACC: 79.61％
# FM AUC: 61.69％
#
#
# Cluster: 95
# FM MSE: 1.9524
# FM ACC: 71.53％
# FM AUC: 55.09％
#
#
# Cluster: 96
# FM MSE: 1.7572
# FM ACC: 62.62％
# FM AUC: 60.85％
#
#
# Cluster: 97
# FM MSE: 1.9878
# FM ACC: 67.35％
# FM AUC: 66.91％
#
#
# Cluster: 98
# FM MSE: 1.8706
# FM ACC: 68.22％
# FM AUC: 62.62％
#
#
# Cluster: 99
# FM MSE: 1.2903
# FM ACC: 84.21％
# FM AUC: 71.67％

# %%
df_concat = pd.concat(RES)
pred_table = pd.pivot_table(df_concat, index="1_user", columns="2_item", values="0_rating")

# %%
pred_table.to_csv("within_category_prediction.csv", encoding='utf-8')

# %%
print("Mean MSE: %.4f" % (sum(MSE.values())/len(MSE)))
print("Mean ACC: %.4f" % (sum(ACC.values())/len(ACC)))
print("Mean AUC: %.4f" % (sum(AUC.values())/len(AUC)))
# Out:
# Mean MSE: 1.6763
# Mean ACC: 72.8696
# Mean AUC: 60.1812

# %%
#res_df = pd.pivot_table(amazon[['reviewer','asin','star_rating']], index='reviewer', columns='asin', values='star_rating',fill_value=0)
#res_df.head()

# %% [markdown]
# ## In-Class Predict

# %%
df_101 = pd.read_csv("df_101.csv")

# %%
def inClassPredict(df):
    RES, MSE, ACC, AUC = dict(), dict(), dict(), dict()
    user_df = df.iloc[:,1:] # first column is "cluster"
    
    # df shape = (100, 91534)
    count = df.shape[1]//500
    for key in range(count):
        start = key * 500
        end = (key+1)*500 if key+1 < count else df.shape[1]
        print("%s to %s" % (start, end))
        
        col = ["cluster"] + user_df.columns[start:end].tolist()
        df_part = df[col]
        melt = pd.melt(df_part, id_vars=['cluster']) # [cluster, variable, value]
        users, items, x_train, x_test, y_train, y_test = preprocess(melt, 'variable', 'cluster', 
                                                    ["cluster", "variable", "value"], 
                                                    rename=["2_item", "1_user", "0_rating"])
        try:
            fm, mse, acc, auc = my_FM(x_train, y_train, x_test, y_test)
            pred, pairs = fill_prediction_matrix(users, items, fm)
            for i, p in enumerate(pred):
                p = 1 if p < 1 else 5 if p > 5 else round(p, 4)
                pairs[i]["0_rating"] = p
            RES[key] = pd.DataFrame(data=pairs)
        except:
            RES[key] = np.nan
            mse, acc, auc = np.nan, np.nan, np.nan

        MSE[key] = mse
        ACC[key] = acc
        AUC[key] = auc
        print("\n")
    return RES, MSE, ACC, AUC

# %%
iRES, iMSE, iACC, iAUC = inClassPredict(df_101)
# Out:
# 0 to 500
# FM MSE: 0.8550
# FM ACC: 97.82％
# FM AUC: 50.64％
#
#
# 500 to 1000
# FM MSE: 1.0899
# FM ACC: 97.66％
# FM AUC: 50.81％
#
#
# 1000 to 1500
# FM MSE: 1.1611
# FM ACC: 97.86％
# FM AUC: 50.91％
#
#
# 1500 to 2000
# FM MSE: 0.7053
# FM ACC: 97.95％
# FM AUC: 51.47％
#
#
# 2000 to 2500
# FM MSE: 1.2764
# FM ACC: 97.86％
# FM AUC: 50.4％
#
#
# 2500 to 3000
# FM MSE: 1.0711
# FM ACC: 97.73％
# FM AUC: 51.52％
#
#
# 3000 to 3500
# FM MSE: 1.0327
# FM ACC: 97.74％
# FM AUC: 51.09％
#
#
# 3500 to 4000
# FM MSE: 1.2019
# FM ACC: 97.92％
# FM AUC: 50.69％
#
#
# 4000 to 4500
# FM MSE: 1.0000
# FM ACC: 97.45％
# FM AUC: 50.71％
#
#
# 4500 to 5000
# FM MSE: 0.9417
# FM ACC: 98.14％
# FM AUC: 50.23％
#
#
# 5000 to 5500
# FM MSE: 1.7445
# FM ACC: 97.75％
# FM AUC: 52.83％
#
#
# 5500 to 6000
# FM MSE: 0.9065
# FM ACC: 97.65％
# FM AUC: 50.57％
#
#
# 6000 to 6500
# FM MSE: 0.5797
# FM ACC: 97.9％
# FM AUC: 50.93％
#
#
# 6500 to 7000
# FM MSE: 0.8440
# FM ACC: 98.18％
# FM AUC: 51.11％
#
#
# 7000 to 7500
# FM MSE: 0.8657
# FM ACC: 97.92％
# FM AUC: 50.43％
#
#
# 7500 to 8000
# FM MSE: 1.3821
# FM ACC: 97.74％
# FM AUC: 51.31％
#
#
# 8000 to 8500
# FM MSE: 1.1523
# FM ACC: 97.71％
# FM AUC: 51.07％
#
#
# 8500 to 9000
# FM MSE: 1.1971
# FM ACC: 97.95％
# FM AUC: 50.96％
#
#
# 9000 to 9500
# FM MSE: 0.7577
# FM ACC: 97.98％
# FM AUC: 50.71％
#
#
# 9500 to 10000
# FM MSE: 0.9723
# FM ACC: 97.62％
# FM AUC: 50.36％
#
#
# 10000 to 10500
# FM MSE: 1.1133
# FM ACC: 97.73％
# FM AUC: 50.61％
#
#
# 10500 to 11000
# FM MSE: 0.8210
# FM ACC: 97.74％
# FM AUC: 51.08％
#
#
# 11000 to 11500
# FM MSE: 0.7422
# FM ACC: 97.84％
# FM AUC: 51.14％
#
#
# 11500 to 12000
# FM MSE: 1.8044
# FM ACC: 97.86％
# FM AUC: 51.38％
#
#
# 12000 to 12500
# FM MSE: 1.1121
# FM ACC: 97.76％
# FM AUC: 50.38％
#
#
# 12500 to 13000
# FM MSE: 0.8388
# FM ACC: 98.13％
# FM AUC: 50.49％
#
#
# 13000 to 13500
# FM MSE: 1.0329
# FM ACC: 97.7％
# FM AUC: 50.83％
#
#
# 13500 to 14000
# FM MSE: 0.9871
# FM ACC: 97.94％
# FM AUC: 51.23％
#
#
# 14000 to 14500
# FM MSE: 0.8689
# FM ACC: 98.03％
# FM AUC: 50.45％
#
#
# 14500 to 15000
# FM MSE: 1.0496
# FM ACC: 97.84％
# FM AUC: 50.14％
#
#
# 15000 to 15500
# FM MSE: 1.2850
# FM ACC: 97.89％
# FM AUC: 50.68％
#
#
# 15500 to 16000
# FM MSE: 0.8731
# FM ACC: 97.91％
# FM AUC: 50.68％
#
#
# 16000 to 16500
# FM MSE: 1.2819
# FM ACC: 97.82％
# FM AUC: 51.62％
#
#
# 16500 to 17000
# FM MSE: 0.9291
# FM ACC: 98.03％
# FM AUC: 51.83％
#
#
# 17000 to 17500
# FM MSE: 1.0531
# FM ACC: 98.14％
# FM AUC: 51.67％
#
#
# 17500 to 18000
# FM MSE: 0.9404
# FM ACC: 97.89％
# FM AUC: 50.66％
#
#
# 18000 to 18500
# FM MSE: 1.1898
# FM ACC: 97.72％
# FM AUC: 50.38％
#
#
# 18500 to 19000
# FM MSE: 1.2009
# FM ACC: 97.92％
# FM AUC: 50.19％
#
#
# 19000 to 19500
# FM MSE: 1.0633
# FM ACC: 97.74％
# FM AUC: 50.37％
#
#
# 19500 to 20000
# FM MSE: 0.9595
# FM ACC: 97.74％
# FM AUC: 51.54％
#
#
# 20000 to 20500
# FM MSE: 1.1232
# FM ACC: 97.69％
# FM AUC: 50.11％
#
#
# 20500 to 21000
# FM MSE: 1.2248
# FM ACC: 97.6％
# FM AUC: 49.89％
#
#
# 21000 to 21500
# FM MSE: 1.3765
# FM ACC: 97.97％
# FM AUC: 51.22％
#
#
# 21500 to 22000
# FM MSE: 0.8684
# FM ACC: 97.76％
# FM AUC: 50.14％
#
#
# 22000 to 22500
# FM MSE: 1.1395
# FM ACC: 97.7％
# FM AUC: 51.74％
#
#
# 22500 to 23000
# FM MSE: 0.9637
# FM ACC: 98.0％
# FM AUC: 50.22％
#
#
# 23000 to 23500
# FM MSE: 1.0339
# FM ACC: 97.96％
# FM AUC: 51.23％
#
#
# 23500 to 24000
# FM MSE: 1.1625
# FM ACC: 97.97％
# FM AUC: 50.17％
#
#
# 24000 to 24500
# FM MSE: 0.6981
# FM ACC: 97.48％
# FM AUC: 50.74％
#
#
# 24500 to 25000
# FM MSE: 1.2320
# FM ACC: 97.86％
# FM AUC: 51.16％
#
#
# 25000 to 25500
# FM MSE: 1.3912
# FM ACC: 98.0％
# FM AUC: 51.76％
#
#
# 25500 to 26000
# FM MSE: 1.1633
# FM ACC: 97.78％
# FM AUC: 51.8％
#
#
# 26000 to 26500
# FM MSE: 1.0129
# FM ACC: 97.7％
# FM AUC: 50.6％
#
#
# 26500 to 27000
# FM MSE: 1.2216
# FM ACC: 97.95％
# FM AUC: 50.42％
#
#
# 27000 to 27500
# FM MSE: 1.3398
# FM ACC: 97.51％
# FM AUC: 50.74％
#
#
# 27500 to 28000
# FM MSE: 1.1937
# FM ACC: 97.61％
# FM AUC: 50.78％
#
#
# 28000 to 28500
# FM MSE: 1.0800
# FM ACC: 98.08％
# FM AUC: 50.76％
#
#
# 28500 to 29000
# FM MSE: 0.8054
# FM ACC: 97.77％
# FM AUC: 49.9％
#
#
# 29000 to 29500
# FM MSE: 0.9267
# FM ACC: 97.65％
# FM AUC: 50.58％
#
#
# 29500 to 30000
# FM MSE: 1.7611
# FM ACC: 98.05％
# FM AUC: 51.02％
#
#
# 30000 to 30500
# FM MSE: 1.1130
# FM ACC: 97.89％
# FM AUC: 50.67％
#
#
# 30500 to 31000
# FM MSE: 0.8034
# FM ACC: 97.9％
# FM AUC: 50.19％
#
#
# 31000 to 31500
# FM MSE: 1.9065
# FM ACC: 97.67％
# FM AUC: 50.35％
#
#
# 31500 to 32000
# FM MSE: 1.0394
# FM ACC: 97.58％
# FM AUC: 51.43％
#
#
# 32000 to 32500
# FM MSE: 0.8584
# FM ACC: 97.57％
# FM AUC: 51.22％
#
#
# 32500 to 33000
# FM MSE: 0.6454
# FM ACC: 97.93％
# FM AUC: 51.67％
#
#
# 33000 to 33500
# FM MSE: 0.5805
# FM ACC: 98.03％
# FM AUC: 50.48％
#
#
# 33500 to 34000
# FM MSE: 1.3714
# FM ACC: 97.92％
# FM AUC: 50.18％
#
#
# 34000 to 34500
# FM MSE: 1.2907
# FM ACC: 97.83％
# FM AUC: 50.64％
#
#
# 34500 to 35000
# FM MSE: 0.9892
# FM ACC: 97.71％
# FM AUC: 51.07％
#
#
# 35000 to 35500
# FM MSE: 1.0153
# FM ACC: 97.59％
# FM AUC: 50.78％
#
#
# 35500 to 36000
# FM MSE: 0.8929
# FM ACC: 97.79％
# FM AUC: 50.65％
#
#
# 36000 to 36500
# FM MSE: 1.0733
# FM ACC: 97.77％
# FM AUC: 50.63％
#
#
# 36500 to 37000
# FM MSE: 1.0569
# FM ACC: 97.82％
# FM AUC: 50.14％
#
#
# 37000 to 37500
# FM MSE: 1.2599
# FM ACC: 97.97％
# FM AUC: 51.48％
#
#
# 37500 to 38000
# FM MSE: 0.8353
# FM ACC: 98.0％
# FM AUC: 50.45％
#
#
# 38000 to 38500
# FM MSE: 1.4460
# FM ACC: 97.6％
# FM AUC: 51.44％
#
#
# 38500 to 39000
# FM MSE: 0.8275
# FM ACC: 97.74％
# FM AUC: 50.39％
#
#
# 39000 to 39500
# FM MSE: 1.3357
# FM ACC: 98.0％
# FM AUC: 50.72％
#
#
# 39500 to 40000
# FM MSE: 1.1079
# FM ACC: 97.8％
# FM AUC: 50.39％
#
#
# 40000 to 40500
# FM MSE: 0.7884
# FM ACC: 97.98％
# FM AUC: 50.47％
#
#
# 40500 to 41000
# FM MSE: 0.7514
# FM ACC: 97.91％
# FM AUC: 50.94％
#
#
# 41000 to 41500
# FM MSE: 1.2985
# FM ACC: 97.91％
# FM AUC: 50.13％
#
#
# 41500 to 42000
# FM MSE: 1.0687
# FM ACC: 97.69％
# FM AUC: 51.28％
#
#
# 42000 to 42500
# FM MSE: 1.0496
# FM ACC: 97.9％
# FM AUC: 50.93％
#
#
# 42500 to 43000
# FM MSE: 0.8739
# FM ACC: 97.97％
# FM AUC: 50.41％
#
#
# 43000 to 43500
# FM MSE: 1.1490
# FM ACC: 97.85％
# FM AUC: 50.64％
#
#
# 43500 to 44000
# FM MSE: 1.5402
# FM ACC: 97.9％
# FM AUC: 51.41％
#
#
# 44000 to 44500
# FM MSE: 0.9276
# FM ACC: 97.77％
# FM AUC: 50.39％
#
#
# 44500 to 45000
# FM MSE: 1.3708
# FM ACC: 97.89％
# FM AUC: 50.43％
#
#
# 45000 to 45500
# FM MSE: 0.6507
# FM ACC: 97.67％
# FM AUC: 50.4％
#
#
# 45500 to 46000
# FM MSE: 0.8273
# FM ACC: 98.04％
# FM AUC: 50.46％
#
#
# 46000 to 46500
# FM MSE: 1.1652
# FM ACC: 98.06％
# FM AUC: 50.75％
#
#
# 46500 to 47000
# FM MSE: 0.9564
# FM ACC: 97.79％
# FM AUC: 51.11％
#
#
# 47000 to 47500
# FM MSE: 0.6973
# FM ACC: 97.74％
# FM AUC: 50.85％
#
#
# 47500 to 48000
# FM MSE: 0.9179
# FM ACC: 97.81％
# FM AUC: 50.64％
#
#
# 48000 to 48500
# FM MSE: 0.9140
# FM ACC: 97.82％
# FM AUC: 50.64％
#
#
# 48500 to 49000
# FM MSE: 0.8277
# FM ACC: 97.78％
# FM AUC: 50.16％
#
#
# 49000 to 49500
# FM MSE: 1.0705
# FM ACC: 97.73％
# FM AUC: 52.0％
#
#
# 49500 to 50000
# FM MSE: 1.5236
# FM ACC: 97.83％
# FM AUC: 50.64％
#
#
# 50000 to 50500
# FM MSE: 0.7438
# FM ACC: 97.93％
# FM AUC: 49.92％
#
#
# 50500 to 51000
# FM MSE: 1.0237
# FM ACC: 97.75％
# FM AUC: 50.85％
#
#
# 51000 to 51500
# FM MSE: 1.2062
# FM ACC: 97.68％
# FM AUC: 51.28％
#
#
# 51500 to 52000
# FM MSE: 1.5693
# FM ACC: 97.87％
# FM AUC: 50.91％
#
#
# 52000 to 52500
# FM MSE: 0.8417
# FM ACC: 97.81％
# FM AUC: 50.36％
#
#
# 52500 to 53000
# FM MSE: 0.7958
# FM ACC: 98.05％
# FM AUC: 50.15％
#
#
# 53000 to 53500
# FM MSE: 1.0790
# FM ACC: 97.73％
# FM AUC: 51.08％
#
#
# 53500 to 54000
# FM MSE: 0.9732
# FM ACC: 97.75％
# FM AUC: 51.09％
#
#
# 54000 to 54500
# FM MSE: 1.5827
# FM ACC: 97.68％
# FM AUC: 51.52％
#
#
# 54500 to 55000
# FM MSE: 0.9801
# FM ACC: 97.85％
# FM AUC: 50.13％
#
#
# 55000 to 55500
# FM MSE: 1.2764
# FM ACC: 97.72％
# FM AUC: 51.32％
#
#
# 55500 to 56000
# FM MSE: 0.7729
# FM ACC: 97.88％
# FM AUC: 50.67％
#
#
# 56000 to 56500
# FM MSE: 0.9692
# FM ACC: 97.61％
# FM AUC: 51.01％
#
#
# 56500 to 57000
# FM MSE: 0.9203
# FM ACC: 97.91％
# FM AUC: 50.12％
#
#
# 57000 to 57500
# FM MSE: 1.3209
# FM ACC: 97.51％
# FM AUC: 51.18％
#
#
# 57500 to 58000
# FM MSE: 0.9375
# FM ACC: 98.01％
# FM AUC: 51.27％
#
#
# 58000 to 58500
# FM MSE: 0.8163
# FM ACC: 97.8％
# FM AUC: 50.39％
#
#
# 58500 to 59000
# FM MSE: 1.1717
# FM ACC: 97.86％
# FM AUC: 50.91％
#
#
# 59000 to 59500
# FM MSE: 0.9502
# FM ACC: 97.74％
# FM AUC: 50.85％
#
#
# 59500 to 60000
# FM MSE: 1.6061
# FM ACC: 97.66％
# FM AUC: 51.77％
#
#
# 60000 to 60500
# FM MSE: 0.8472
# FM ACC: 97.85％
# FM AUC: 50.9％
#
#
# 60500 to 61000
# FM MSE: 0.9545
# FM ACC: 97.84％
# FM AUC: 51.4％
#
#
# 61000 to 61500
# FM MSE: 0.8030
# FM ACC: 97.83％
# FM AUC: 50.89％
#
#
# 61500 to 62000
# FM MSE: 0.6265
# FM ACC: 98.07％
# FM AUC: 50.76％
#
#
# 62000 to 62500
# FM MSE: 1.1569
# FM ACC: 97.92％
# FM AUC: 50.69％
#
#
# 62500 to 63000
# FM MSE: 0.8588
# FM ACC: 97.62％
# FM AUC: 50.56％
#
#
# 63000 to 63500
# FM MSE: 0.8581
# FM ACC: 97.97％
# FM AUC: 50.42％
#
#
# 63500 to 64000
# FM MSE: 1.1357
# FM ACC: 97.84％
# FM AUC: 50.66％
#
#
# 64000 to 64500
# FM MSE: 1.0406
# FM ACC: 97.77％
# FM AUC: 50.61％
#
#
# 64500 to 65000
# FM MSE: 0.7444
# FM ACC: 97.87％
# FM AUC: 50.68％
#
#
# 65000 to 65500
# FM MSE: 0.9873
# FM ACC: 97.92％
# FM AUC: 51.19％
#
#
# 65500 to 66000
# FM MSE: 1.4015
# FM ACC: 97.96％
# FM AUC: 50.71％
#
#
# 66000 to 66500
# FM MSE: 0.7026
# FM ACC: 97.96％
# FM AUC: 50.96％
#
#
# 66500 to 67000
# FM MSE: 1.0487
# FM ACC: 97.75％
# FM AUC: 50.85％
#
#
# 67000 to 67500
# FM MSE: 1.0572
# FM ACC: 97.87％
# FM AUC: 49.86％
#
#
# 67500 to 68000
# FM MSE: 0.9257
# FM ACC: 97.69％
# FM AUC: 50.62％
#
#
# 68000 to 68500
# FM MSE: 1.0518
# FM ACC: 97.9％
# FM AUC: 50.41％
#
#
# 68500 to 69000
# FM MSE: 1.2616
# FM ACC: 97.83％
# FM AUC: 50.4％
#
#
# 69000 to 69500
# FM MSE: 0.9143
# FM ACC: 97.74％
# FM AUC: 50.85％
#
#
# 69500 to 70000
# FM MSE: 1.5261
# FM ACC: 97.83％
# FM AUC: 50.89％
#
#
# 70000 to 70500
# FM MSE: 0.7762
# FM ACC: 97.92％
# FM AUC: 51.2％
#
#
# 70500 to 71000
# FM MSE: 1.0179
# FM ACC: 97.53％
# FM AUC: 50.77％
#
#
# 71000 to 71500
# FM MSE: 1.1887
# FM ACC: 97.51％
# FM AUC: 50.52％
#
#
# 71500 to 72000
# FM MSE: 0.7389
# FM ACC: 97.86％
# FM AUC: 50.91％
#
#
# 72000 to 72500
# FM MSE: 0.9790
# FM ACC: 97.82％
# FM AUC: 50.89％
#
#
# 72500 to 73000
# FM MSE: 1.4041
# FM ACC: 97.63％
# FM AUC: 50.35％
#
#
# 73000 to 73500
# FM MSE: 1.2647
# FM ACC: 97.85％
# FM AUC: 50.9％
#
#
# 73500 to 74000
# FM MSE: 0.9921
# FM ACC: 98.02％
# FM AUC: 50.2％
#
#
# 74000 to 74500
# FM MSE: 0.9811
# FM ACC: 97.9％
# FM AUC: 49.9％
#
#
# 74500 to 75000
# FM MSE: 1.1659
# FM ACC: 98.02％
# FM AUC: 52.26％
#
#
# 75000 to 75500
# FM MSE: 1.1280
# FM ACC: 97.96％
# FM AUC: 52.6％
#
#
# 75500 to 76000
# FM MSE: 1.1808
# FM ACC: 97.96％
# FM AUC: 50.97％
#
#
# 76000 to 76500
# FM MSE: 0.7015
# FM ACC: 97.85％
# FM AUC: 50.18％
#
#
# 76500 to 77000
# FM MSE: 1.2986
# FM ACC: 97.74％
# FM AUC: 51.33％
#
#
# 77000 to 77500
# FM MSE: 1.2445
# FM ACC: 97.51％
# FM AUC: 50.97％
#
#
# 77500 to 78000
# FM MSE: 1.3899
# FM ACC: 97.71％
# FM AUC: 50.39％
#
#
# 78000 to 78500
# FM MSE: 0.7867
# FM ACC: 97.76％
# FM AUC: 50.63％
#
#
# 78500 to 79000
# FM MSE: 1.0505
# FM ACC: 97.97％
# FM AUC: 50.44％
#
#
# 79000 to 79500
# FM MSE: 1.2160
# FM ACC: 97.91％
# FM AUC: 50.93％
#
#
# 79500 to 80000
# FM MSE: 1.0883
# FM ACC: 97.75％
# FM AUC: 50.15％
#
#
# 80000 to 80500
# FM MSE: 1.0545
# FM ACC: 97.91％
# FM AUC: 51.66％
#
#
# 80500 to 81000
# FM MSE: 1.4041
# FM ACC: 97.94％
# FM AUC: 50.95％
#
#
# 81000 to 81500
# FM MSE: 0.9409
# FM ACC: 97.75％
# FM AUC: 50.38％
#
#
# 81500 to 82000
# FM MSE: 1.0740
# FM ACC: 97.81％
# FM AUC: 51.58％
#
#
# 82000 to 82500
# FM MSE: 1.1574
# FM ACC: 97.98％
# FM AUC: 50.71％
#
#
# 82500 to 83000
# FM MSE: 1.3882
# FM ACC: 97.84％
# FM AUC: 50.66％
#
#
# 83000 to 83500
# FM MSE: 0.5989
# FM ACC: 97.83％
# FM AUC: 50.39％
#
#
# 83500 to 84000
# FM MSE: 1.3979
# FM ACC: 98.03％
# FM AUC: 50.44％
#
#
# 84000 to 84500
# FM MSE: 1.1555
# FM ACC: 98.09％
# FM AUC: 50.19％
#
#
# 84500 to 85000
# FM MSE: 1.1224
# FM ACC: 97.71％
# FM AUC: 51.07％
#
#
# 85000 to 85500
# FM MSE: 1.2775
# FM ACC: 97.87％
# FM AUC: 50.91％
#
#
# 85500 to 86000
# FM MSE: 1.2779
# FM ACC: 98.03％
# FM AUC: 50.47％
#
#
# 86000 to 86500
# FM MSE: 1.0899
# FM ACC: 97.67％
# FM AUC: 50.81％
#
#
# 86500 to 87000
# FM MSE: 1.0516
# FM ACC: 97.67％
# FM AUC: 51.04％
#
#
# 87000 to 87500
# FM MSE: 0.7974
# FM ACC: 97.96％
# FM AUC: 50.96％
#
#
# 87500 to 88000
# FM MSE: 0.6998
# FM ACC: 97.96％
# FM AUC: 50.45％
#
#
# 88000 to 88500
# FM MSE: 1.0551
# FM ACC: 97.93％
# FM AUC: 50.41％
#
#
# 88500 to 89000
# FM MSE: 1.4184
# FM ACC: 97.64％
# FM AUC: 50.55％
#
#
# 89000 to 89500
# FM MSE: 1.3119
# FM ACC: 97.6％
# FM AUC: 50.32％
#
#
# 89500 to 90000
# FM MSE: 1.2372
# FM ACC: 97.71％
# FM AUC: 50.59％
#
#
# 90000 to 90500
# FM MSE: 1.1641
# FM ACC: 97.91％
# FM AUC: 50.67％
#
#
# 90500 to 91000
# FM MSE: 1.8024
# FM ACC: 97.68％
# FM AUC: 50.58％
#
#
# 91000 to 91534
# FM MSE: 0.9540
# FM ACC: 97.95％
# FM AUC: 50.65％

# %%
idf_concat = pd.concat(iRES)
ipred_table = pd.pivot_table(idf_concat, index="2_item", columns="1_user", values="0_rating")

# %%
ipred_table.to_csv("inclass_prediction.csv", encoding='utf-8')

# %%
ipred_table.head()
# Out:
# 1_user     A00039763E5V43M02Z3YZ  A00111163LLS4KLYZXNZL  \
# 2_item
# cluster0                     1.0                    1.0
# cluster1                     1.0                    1.0
# cluster10                    1.0                    1.0
# cluster11                    1.0                    1.0
# cluster12                    1.0                    1.0
#
# 1_user     A002359833QJM7OQHCXWY  A00236702NOP1FKXVRFN3  A0026556YRYONJ90H57Z  \
# 2_item
# cluster0                     1.0                    1.0                   1.0
# cluster1                     1.0                    1.0                   1.0
# cluster10                    1.0                    1.0                   1.0
# cluster11                    1.0                    1.0                   1.0
# cluster12                    1.0                    1.0                   1.0
#
# 1_user     A00281722IA12Z7XNGMJV  A0037670NPLI11RBWYFA  A0038872349TB5N0JHQQW  \
# 2_item
# cluster0                     1.0                   1.0                    1.0
# cluster1                     1.0                   1.0                    1.0
# cluster10                    1.0                   1.0                    1.0
# cluster11                    1.0                   1.0                    1.0
# cluster12                    1.0                   1.0                    1.0
#
# 1_user     A004257029HNEB0RA4Z6V  A00440181FM3TJMYVT608      ...        \
# 2_item                                                       ...
# cluster0                     1.0                    1.0      ...
# cluster1                     1.0                    1.0      ...
# cluster10                    1.0                    1.0      ...
# cluster11                    1.0                    1.0      ...
# cluster12                    1.0                    1.0      ...
#
# 1_user     AZZIR7GU8SMIR  AZZJ1H7DM2UQD  AZZJG13YQANEA  AZZN34VU2X737  \
# 2_item
# cluster0             1.0            1.0            1.0            1.0
# cluster1             1.0            1.0            1.0            1.0
# cluster10            1.0            1.0            1.0            1.0
# cluster11            1.0            1.0            1.0            1.0
# cluster12            1.0            1.0            1.0            1.0
#
# 1_user     AZZN3MTTZHA74  AZZNEMLU7N9ET  AZZNWOFUDH8S2  AZZPCFDGCFI0D  \
# 2_item
# cluster0             1.0            1.0            1.0            1.0
# cluster1             1.0            1.0            1.0            1.0
# cluster10            1.0            1.0            1.0            1.0
# cluster11            1.0            1.0            1.0            1.0
# cluster12            1.0            1.0            1.0            1.0
#
# 1_user     AZZQ97SNW14J1  AZZYKX2KZ0Q82
# 2_item
# cluster0             1.0            1.0
# cluster1             1.0            1.0
# cluster10            1.0            1.0
# cluster11            1.0            1.0
# cluster12            1.0            1.0
#
# [5 rows x 91533 columns]

# %%
print("Mean iMSE: %.4f" % (sum(iMSE.values())/len(iMSE)))
print("Mean iACC: %.4f" % (sum(iACC.values())/len(iACC)))
print("Mean iAUC: %.4f" % (sum(iAUC.values())/len(iAUC)))
# Out:
# Mean iMSE: 1.0704
# Mean iACC: 97.8285
# Mean iAUC: 50.7910
